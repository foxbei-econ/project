# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
# df_DA
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %%
df_DA_explode= df_DA.explode('job_skills')
df_DA_explode.head(3)
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# 1 2023-01-14 13:18:07                  False                 False
# 1 2023-01-14 13:18:07                  False                 False
#
#   job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 1      Mexico        None              NaN              NaN
# ...

# %%
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills',  aggfunc='size', fill_value=0)

df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
# Create a total row
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
# Order columns by total count
index_tot = df_DA_pivot.loc['Total'].sort_values(ascending=False).index
df_DA_pivot = df_DA_pivot[index_tot]
# # Drop total row
# df_DA_pivot = df_DA_pivot.drop('Total')
# df_DA_sort.index
df_PA_pivot = df_PA_pivot[['sql','python']]
df_PA_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 1 to Total
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sql     13 non-null     int64
#  1   python  13 non-null     int64
# dtypes: int64(2)
# memory usage: 868.0+ bytes

# %%
data = {
    'job_title': ['Data Scientist', 'Data Scientist', 'Analyst', 'Analyst', 'Data Scientist'],
    'job_skills': ['Python', 'SQL', 'Excel', 'Python', 'Python']
}

df = pd.DataFrame(data)
df
# result = df.groupby(['job_title', 'job_skills']).size()
# print(result)
# Out:
#         job_title job_skills
# 0  Data Scientist     Python
# 1  Data Scientist        SQL
# 2         Analyst      Excel
# 3         Analyst     Python
# 4  Data Scientist     Python
